# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
telemetry_data_fp = "./Telemetry Data"
# For now, we will only have 1 Data Frame for 1 telemetry file
df = pd.read_csv(telemetry_data_fp + "/T1_Baku_FP2.csv", sep='\t')
# Show first 5 rows
df.head(5)
# Out:
#      carId trackId  trackLength  lapIndex  lapNum  lapFlag  binIndex  \
# 0  Renault    Baku         5994         0       0        0         0
# 1  Renault    Baku         5994         0       0        0         1
# 2  Renault    Baku         5994         0       0        0         2
# 3  Renault    Baku         5994         0       0        0         3
# 4  Renault    Baku         5994         0       0        0         4
#
#    validBin  lap_number  lap_distance  ...  front_left_wing_damage  \
# 0         1           0       1.41686  ...                    0.32
# 1         1           0       1.41686  ...                    0.32
# 2         1           0       2.39192  ...                    0.32
# 3         1           0       3.36697  ...                    0.32
# 4         1           0       4.34202  ...                    0.32
#
#    front_right_wing_damage  rear_wing_damage  engine_damage  gear_box_damage  \
# 0                      0.0                 0           0.66              0.4
# 1                      0.0                 0           0.66              0.4
# 2                      0.0                 0           0.66              0.4
# 3                      0.0                 0           0.66              0.4
# 4                      0.0                 0           0.66              0.4
#
#    ers_store  ers_deployMode  ers_harv_mguk  ers_harv_mguh  ers_deployed
# 0  3502060.0               2       202249.0       933189.0     1622660.0
# 1  3502060.0               2       202249.0       933189.0     1622660.0
# 2  3501810.0               2       161799.0       746551.0     1298190.0
# 3  3501560.0               2       121349.0       559913.0      973724.0
# 4  3501310.0               2        80899.6       373276.0      649254.0
#
# [5 rows x 161 columns]

# %%
# We want to get the list of data categories
data_categories = list(df.columns)
print(data_categories)
# Out:
# ['carId', 'trackId', 'trackLength', 'lapIndex', 'lapNum', 'lapFlag', 'binIndex', 'validBin', 'lap_number', 'lap_distance', 'lap_time', 'lap_time_invalid', 'world_position_X', 'world_position_Y', 'world_position_Z', 'world_forward_X', 'world_forward_Y', 'world_forward_Z', 'world_right_X', 'world_right_Y', 'world_right_Z', 'velocity_X', 'velocity_Y', 'velocity_Z', 'gforce_X', 'gforce_Y', 'gforce_Z', 'pit_status', 'race_position', 'flags_status', 'throttle', 'brake', 'clutch', 'steering', 'gear', 'rpm', 'rpm_perc', 'fuel', 'tyre_compound_0', 'tyre_compound_1', 'tyre_compound_2', 'tyre_compound_3', 'yaw', 'pitch', 'roll', 'susp_pos_0', 'susp_pos_1', 'susp_pos_2', 'susp_pos_3', 'susp_vel_0', 'susp_vel_1', 'susp_vel_2', 'susp_vel_3', 'susp_acc_0', 'susp_acc_1', 'susp_acc_2', 'susp_acc_3', 'wheel_speed_0', 'wheel_speed_1', 'wheel_speed_2', 'wheel_speed_3', 'wheel_slip_ratio_0', 'wheel_slip_ratio_1', 'wheel_slip_ratio_2', 'wheel_slip_ratio_3', 'wheel_slip_angle_0', 'wheel_slip_angle_1', 'wheel_slip_angle_2', 'wheel_slip_angle_3', 'angular_vel_X', 'angular_vel_Y', 'angular_vel_Z', 'angular_acc_X', 'angular_acc_Y', 'angular_acc_Z', 'weather', 'track_temp', 'air_temp', 'pitSpeedLimit', 'safetyCarStatus', 'networkGame', 'safetyCarDelta', 'penalties', 'startGridPosition', 'wing_setup_0', 'wing_setup_1', 'diff_onThrottle_setup', 'diff_offThrottle_setup', 'camber_setup_0', 'camber_setup_1', 'camber_setup_2', 'camber_setup_3', 'toe_setup_0', 'toe_setup_1', 'toe_setup_2', 'toe_setup_3', 'susp_spring_setup_0', 'susp_spring_setup_1', 'susp_spring_setup_2', 'susp_spring_setup_3', 'arb_setup_0', 'arb_setup_1', 'susp_height_setup_0', 'susp_height_setup_1', 'susp_height_setup_2', 'susp_height_setup_3', 'brake_press_setup', 'brake_bias_setup', 'tyre_press_setup_0', 'tyre_press_setup_1', 'tyre_press_setup_2', 'tyre_press_setup_3', 'ballast_setup', 'fuel_setup', 'drs', 'brake_temp_0', 'brake_temp_1', 'brake_temp_2', 'brake_temp_3', 'tyre_temp_0', 'tyre_temp_1', 'tyre_temp_2', 'tyre_temp_3', 'tyre_tempInternalAir_0', 'tyre_tempInternalAir_1', 'tyre_tempInternalAir_2', 'tyre_tempInternalAir_3', 'tyre_press_0', 'tyre_press_1', 'tyre_press_2', 'tyre_press_3', 'terrain_0', 'terrain_1', 'terrain_2', 'terrain_3', 'engine_temp', 'traction_ctrl_setup', 'abs_setup', 'fuel_type', 'fuel_remainingLaps', 'front_brake_bias', 'pit_limiter', 'drs_allowed', 'tyre_wear_0', 'tyre_wear_1', 'tyre_wear_2', 'tyre_wear_3', 'tyre_damage_0', 'tyre_damage_1', 'tyre_damage_2', 'tyre_damage_3', 'front_left_wing_damage', 'front_right_wing_damage', 'rear_wing_damage', 'engine_damage', 'gear_box_damage', 'ers_store', 'ers_deployMode', 'ers_harv_mguk', 'ers_harv_mguh', 'ers_deployed']

# %%
# Let's try grouping by lap indexes and see what trends we can find, such as avg times between them
